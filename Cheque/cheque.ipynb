# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("sample.jpeg")

# %%
plt.title("original image")
plt.imshow(image)

# %%
cropped = image[400:480,200:600]
plt.imshow(cropped)

# %%
cropped2 = image[50:100,100:450]
plt.imshow(cropped2)

# %%
cropped3 = image[0:50,780:950]
plt.imshow(cropped3)

# %%
cropped4 = image[140:190,710:950]
plt.imshow(cropped4)

# %%
print(cropped4)
# Out:
# [[[  5  10   0]
#   [ 76  84  67]
#   [243 253 230]
#   ...
#   [250 247 232]
#   [255 250 254]
#   [255 246 255]]
#
#  [[  0   5   0]
#   [ 51  61  44]
#   [237 250 226]
#   ...
#   [234 237 211]
#   [240 220 219]
#   [208 190 203]]
#
#  [[  0   5   3]
#   [ 52  59  52]
#   [247 255 241]
#   ...
#   [226 237 199]
#   [255 245 233]
#   [221 207 213]]
#
#  ...
#
#  [[ 41  51  51]
#   [  4  13  10]
#   [  9   0   0]
#   ...
#   [  9   1   2]
#   [  7   0   0]
#   [ 58  62  51]]
#
#  [[ 55  65  65]
#   [  0   4   1]
#   [  9   0   0]
#   ...
#   [218 213 214]
#   [220 209 205]
#   [236 232 221]]
#
#  [[ 36  47  45]
#   [  0   2   0]
#   [  4   1   0]
#   ...
#   [153 151 150]
#   [250 234 228]
#   [214 202 190]]]

# %%
cropped5 = image[140:190,710:950]
plt.imshow(cropped5)

# %%
print(cropped4 == cropped5)
# Out:
# [[[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]
#
#  [[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]
#
#  [[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]
#
#  ...
#
#  [[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]
#
#  [[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]
#
#  [[ True  True  True]
#   [ True  True  True]
#   [ True  True  True]
#   ...
#   [ True  True  True]
#   [ True  True  True]
#   [ True  True  True]]]

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
print(pytesseract.image_to_string(cropped))
# Out:
# w243053" 6000 280b3"
